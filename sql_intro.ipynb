# %%
import pandas as pd
import requests

url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.json"
response = requests.get(url)
data = response.json()

# Convert to DataFrame
df = pd.DataFrame(data)

df = df.rename(columns={
    ':@computed_region_efsh_h5xi': 'computed_region_efsh_h5xi',
    ':@computed_region_f5dn_yrer': 'computed_region_f5dn_yrer',
    ':@computed_region_yeji_bk3q': 'computed_region_yeji_bk3q',
    ':@computed_region_92fq_4b7q': 'computed_region_92fq_4b7q',
    ':@computed_region_sbqj_enih': 'computed_region_sbqj_enih',
    ':@computed_region_7mpf_4k6g': 'computed_region_7mpf_4k6g'
})

# Show first rows
df.head(5)
# Out:
#   unique_key             created_date agency                      agency_name  \
# 0   64291325  2025-03-09T00:51:36.000   NYPD  New York City Police Department
# 1   64291289  2025-03-09T00:51:29.000    TLC    Taxi and Limousine Commission
# 2   64292704  2025-03-09T00:51:12.000   NYPD  New York City Police Department
# 3   64291400  2025-03-09T00:51:10.000   NYPD  New York City Police Department
# 4   64295640  2025-03-09T00:49:53.000   NYPD  New York City Police Department
#
#                complaint_type                        descriptor  \
# 0          Noise - Commercial                  Loud Music/Party
# 1  For Hire Vehicle Complaint  Driver Complaint - Non Passenger
# 2         Noise - Residential                  Loud Music/Party
# 3         Noise - Residential                  Banging/Pounding
# 4         Noise - Residential                  Loud Music/Party
#
#                 location_type incident_zip        incident_address  \
# ...

# %%
df.head(500000).to_csv("nyc_311_service_requests.csv", index=False)

# %%
df.head(500000).to_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/nyc_311_service_requests.csv', index=False)

# %%
print(df.dtypes)
# Out:
# unique_key                        object
# created_date                      object
# agency                            object
# agency_name                       object
# complaint_type                    object
# descriptor                        object
# location_type                     object
# incident_zip                      object
# incident_address                  object
# street_name                       object
# cross_street_1                    object
# cross_street_2                    object
# intersection_street_1             object
# intersection_street_2             object
# address_type                      object
# city                              object
# landmark                          object
# status                            object
# community_board                   object
# bbl                               object
# borough                           object
# x_coordinate_state_plane          object
# y_coordinate_state_plane          object
# ...

# %%
unique_values_count = df["address_type"].nunique()
print(unique_values_count)
print(df["address_type"].value_counts())
# Out:
# 4
# address_type
# ADDRESS         960
# INTERSECTION     30
# UNRECOGNIZED      5
# BLOCKFACE         4
# Name: count, dtype: int64
